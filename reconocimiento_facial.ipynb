# %%
from google.colab import drive
drive.mount("/content/d")
fPath = "d/MyDrive/faceDetectio n/"
# Out:
# Mounted at /content/d

# %%
import cv2
import os
import shutil
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

params = {
    "imagePath": "d/MyDrive/faceDetection/image.jpg",
    "cascadePath": "d/MyDrive/faceDetection/haarcascade_frontalface_default.xml"
}

# %% [markdown]
# # STATIC PHOTO

# %%
# get cv cascade 
shutil.copy(params["cascadePath"], "haarcascade_frontalface_default.xml")
face_сascade = cv2.CascadeClassifier(
    os.path.join(
        cv2.data.haarcascades,
        "haarcascade_frontalface_default.xml"
    )
)

# %%
# get image
img = cv2.imread(params["imagePath"])
plt.imshow(img);

# %%
# switch image to grayscale
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img);

# %%
faces = face_сascade.detectMultiScale(
    img,
    scaleFactor=1.5, # compensates objects' diff distance
    minNeighbors=5, # objects detected near moving window
    minSize=(40, 40), # moving window size
    flags = cv2.CASCADE_SCALE_IMAGE
)
print(f"no of the objects detected: {len(faces)}")
print(faces)
# Out:
# no of the objects detected: 4
# [[751  98 182 182]
#  [108 152 182 182]
#  [350 187 182 182]
#  [617 222 122 122]]

# %%
# get (x, y, width, height) of the rectangle
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1000x665 at 0x7F3953448970>

# %% [markdown]
# # WEBCAM

# %% [markdown]
# check main.py
